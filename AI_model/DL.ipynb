# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# Load csv file from Google drive
file_path = '/content/drive/MyDrive/Colab Notebooks/2024_BNEM/DL/data_pattern_mean.csv'
data = pd.read_csv(file_path)
data
# Out:
#            seq   N5_mean  N50_mean  N500_mean  N5M10_mean  N5M100_mean  AAAAA  \
# 0     TAAAAATT  0.509056  0.582795   0.703277    0.713463     0.674791   True
# 1     TAAAACTT  0.491550  0.571642   0.709767    0.737302     0.782054  False
# 2     TAAAAGTT  0.510142  0.591441   0.720091    0.742541     0.781795  False
# 3     TAAAATTT  0.496465  0.581366   0.709739    0.730826     0.763748  False
# 4     TAAACATT  0.492476  0.568615   0.714035    0.742980     0.776192  False
# ...        ...       ...       ...        ...         ...          ...    ...
# 1019  TTTTGTTT  0.475727  0.568956   0.733198    0.742376     0.787436  False
# 1020  TTTTTATT  0.477428  0.565936   0.743278    0.754569     0.812502  False
# 1021  TTTTTCTT  0.472222  0.554448   0.715267    0.730751     0.791353  False
# 1022  TTTTTGTT  0.475066  0.565352   0.730467    0.743580     0.796328  False
# 1023  TTTTTTTT  0.472607  0.561613   0.725543    0.734755     0.791839  False
#
#       AAAAT  AAAAG  AAAAC  ...  ...CA  ...CT  ...CG  ...CC  ...C.  ....A  \
# 0     False  False  False  ...  False  False  False  False  False   True
# 1     False  False   True  ...  False  False  False  False  False  False
# 2     False   True  False  ...  False  False  False  False  False  False
# 3      True  False  False  ...  False  False  False  False  False  False
# 4     False  False  False  ...   True  False  False  False   True   True
# ...     ...    ...    ...  ...    ...    ...    ...    ...    ...    ...
# 1019  False  False  False  ...  False  False  False  False  False  False
# 1020  False  False  False  ...  False  False  False  False  False   True
# 1021  False  False  False  ...  False  False  False  False  False  False
# 1022  False  False  False  ...  False  False  False  False  False  False
# 1023  False  False  False  ...  False  False  False  False  False  False
#
#       ....T  ....G  ....C  .....
# 0     False  False  False   True
# 1     False  False   True   True
# 2     False   True  False   True
# 3      True  False  False   True
# 4     False  False  False   True
# ...     ...    ...    ...    ...
# 1019   True  False  False   True
# 1020  False  False  False   True
# 1021  False  False   True   True
# 1022  False   True  False   True
# 1023   True  False  False   True
#
# [1024 rows x 3131 columns]

# %%
col_to_drop = ['seq', 'N5_mean', 'N50_mean', 'N500_mean', 'N5M10_mean', 'N5M100_mean', '.....']
X = data.drop(columns = col_to_drop, inplace=False)

y_N5 = data[col_to_drop[1]] # N5_mean
y_N50 = data[col_to_drop[2]] # N50_mean
y_N500 = data[col_to_drop[3]] # N500_mean
y_N5M10 = data[col_to_drop[4]] # N5M10_mean
y_N5M100 = data[col_to_drop[5]] # N5M100_mean

# %%
X.shape
# Out:
# (1024, 3124)

# %% [markdown]
# # Deeplearning Model
# There 2 models in each type of solution. \
# Model 1. 1 hidden layer with 256 hidden nodes  (light ver.) \
# Model 2. 3 hidden layers with 1024, 256, 32 hidden nodes respectively (deep ver.) \
# \
# Default Hyperparmeters of model \
# - activation func : relu (last: linear) \
# - optimizer: adam \
# - loss metric: MSE \
# - epochs=10, batch_size=32 \
# - test metrics: MSE, RMSE, MAE \

# %% [markdown]
# # N5

# %%
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_N5, test_size=0.2, random_state=42)

# %%
print("model1 of N5\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model1 of N5
#
# Epoch 1/10
# 26/26 [==============================] - 1s 10ms/step - loss: 0.0428 - mse: 0.0428 - mae: 0.1659
# Epoch 2/10
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0391 - mse: 0.0391 - mae: 0.1653
# Epoch 3/10
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0693
# Epoch 4/10
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0381
# Epoch 5/10
# 26/26 [==============================] - 0s 11ms/step - loss: 9.4635e-04 - mse: 9.4635e-04 - mae: 0.0238
# Epoch 6/10
# 26/26 [==============================] - 0s 10ms/step - loss: 5.1506e-04 - mse: 5.1506e-04 - mae: 0.0170
# Epoch 7/10
# 26/26 [==============================] - 0s 12ms/step - loss: 3.2333e-04 - mse: 3.2333e-04 - mae: 0.0133
# Epoch 8/10
# 26/26 [==============================] - 0s 10ms/step - loss: 2.5537e-04 - mse: 2.5537e-04 - mae: 0.0118
# Epoch 9/10
# 26/26 [==============================] - 0s 11ms/step - loss: 2.3534e-04 - mse: 2.3534e-04 - mae: 0.0112
# Epoch 10/10
# 26/26 [==============================] - 0s 11ms/step - loss: 2.8671e-04 - mse: 2.8671e-04 - mae: 0.0122
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0470
#
# Test MSE: 0.003274542512372136
# Test RMSE: 0.05722361848373568
# Test MAE: 0.04701348766684532

# %%
print("model2 of N5\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(3124,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model2 of N5
#
# Epoch 1/10
# 26/26 [==============================] - 2s 45ms/step - loss: 0.0219 - mse: 0.0219 - mae: 0.0987
# Epoch 2/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0694
# Epoch 3/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0482
# Epoch 4/10
# 26/26 [==============================] - 2s 68ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0352
# Epoch 5/10
# 26/26 [==============================] - 2s 67ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292
# Epoch 6/10
# 26/26 [==============================] - 2s 67ms/step - loss: 8.7910e-04 - mse: 8.7910e-04 - mae: 0.0226
# Epoch 7/10
# 26/26 [==============================] - 1s 48ms/step - loss: 6.5642e-04 - mse: 6.5642e-04 - mae: 0.0193
# Epoch 8/10
# 26/26 [==============================] - 1s 44ms/step - loss: 4.3813e-04 - mse: 4.3813e-04 - mae: 0.0165
# Epoch 9/10
# 26/26 [==============================] - 1s 43ms/step - loss: 3.1858e-04 - mse: 3.1858e-04 - mae: 0.0138
# Epoch 10/10
# 26/26 [==============================] - 1s 44ms/step - loss: 2.3396e-04 - mse: 2.3396e-04 - mae: 0.0117
# 7/7 [==============================] - 0s 10ms/step - loss: 6.0944e-04 - mse: 6.0944e-04 - mae: 0.0208
#
# Test MSE: 0.0006094361888244748
# Test RMSE: 0.024686761408181407
# Test MAE: 0.020756462588906288

# %% [markdown]
# # N50

# %%
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_N50, test_size=0.2, random_state=42)

# %%
print("model1 of N50\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model1 of N50
#
# Epoch 1/10
# 26/26 [==============================] - 1s 10ms/step - loss: 0.0573 - mse: 0.0573 - mae: 0.1922
# Epoch 2/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1661
# Epoch 3/10
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0731
# Epoch 4/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0367
# Epoch 5/10
# 26/26 [==============================] - 0s 10ms/step - loss: 8.5919e-04 - mse: 8.5919e-04 - mae: 0.0222
# Epoch 6/10
# 26/26 [==============================] - 0s 10ms/step - loss: 4.5421e-04 - mse: 4.5421e-04 - mae: 0.0154
# Epoch 7/10
# 26/26 [==============================] - 0s 11ms/step - loss: 3.7003e-04 - mse: 3.7003e-04 - mae: 0.0140
# Epoch 8/10
# 26/26 [==============================] - 0s 10ms/step - loss: 3.1280e-04 - mse: 3.1280e-04 - mae: 0.0127
# Epoch 9/10
# 26/26 [==============================] - 0s 10ms/step - loss: 3.1336e-04 - mse: 3.1336e-04 - mae: 0.0128
# Epoch 10/10
# 26/26 [==============================] - 0s 10ms/step - loss: 3.3143e-04 - mse: 3.3143e-04 - mae: 0.0135
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0422
#
# Test MSE: 0.002742068376392126
# Test RMSE: 0.05236476273594798
# Test MAE: 0.04222442954778671

# %%
print("model2 of N50\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(3124,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model2 of N50
#
# Epoch 1/10
# 26/26 [==============================] - 2s 53ms/step - loss: 0.0324 - mse: 0.0324 - mae: 0.1168
# Epoch 2/10
# 26/26 [==============================] - 2s 67ms/step - loss: 0.0093 - mse: 0.0093 - mae: 0.0804
# Epoch 3/10
# 26/26 [==============================] - 2s 66ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0505
# Epoch 4/10
# 26/26 [==============================] - 1s 56ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0361
# Epoch 5/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0281
# Epoch 6/10
# 26/26 [==============================] - 1s 42ms/step - loss: 8.5720e-04 - mse: 8.5720e-04 - mae: 0.0228
# Epoch 7/10
# 26/26 [==============================] - 1s 43ms/step - loss: 6.8020e-04 - mse: 6.8020e-04 - mae: 0.0200
# Epoch 8/10
# 26/26 [==============================] - 1s 42ms/step - loss: 5.6355e-04 - mse: 5.6355e-04 - mae: 0.0184
# Epoch 9/10
# 26/26 [==============================] - 1s 43ms/step - loss: 4.7597e-04 - mse: 4.7597e-04 - mae: 0.0164
# Epoch 10/10
# 26/26 [==============================] - 1s 41ms/step - loss: 4.1816e-04 - mse: 4.1816e-04 - mae: 0.0158
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0298
#
# Test MSE: 0.0011796840699389577
# Test RMSE: 0.03434652922696786
# Test MAE: 0.029773404821753502

# %% [markdown]
# # N500

# %%
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_N500, test_size=0.2, random_state=42)

# %%
print("model1 of N500\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model1 of N500
#
# Epoch 1/10
# 26/26 [==============================] - 1s 15ms/step - loss: 0.0882 - mse: 0.0882 - mae: 0.2350
# Epoch 2/10
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0484 - mse: 0.0484 - mae: 0.1810
# Epoch 3/10
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0841
# Epoch 4/10
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0470
# Epoch 5/10
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0306
# Epoch 6/10
# 26/26 [==============================] - 0s 14ms/step - loss: 9.4290e-04 - mse: 9.4290e-04 - mae: 0.0235
# Epoch 7/10
# 26/26 [==============================] - 0s 10ms/step - loss: 7.0489e-04 - mse: 7.0489e-04 - mae: 0.0199
# Epoch 8/10
# 26/26 [==============================] - 0s 10ms/step - loss: 5.8126e-04 - mse: 5.8126e-04 - mae: 0.0179
# Epoch 9/10
# 26/26 [==============================] - 0s 10ms/step - loss: 7.5330e-04 - mse: 7.5330e-04 - mae: 0.0201
# Epoch 10/10
# 26/26 [==============================] - 0s 10ms/step - loss: 9.1346e-04 - mse: 9.1346e-04 - mae: 0.0221
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0545
#
# Test MSE: 0.004455178044736385
# Test RMSE: 0.06674712012316625
# Test MAE: 0.05451209470629692

# %%
print("model2 of N500\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(3124,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model2 of N500
#
# Epoch 1/10
# 26/26 [==============================] - 2s 46ms/step - loss: 0.0566 - mse: 0.0566 - mae: 0.1680
# Epoch 2/10
# 26/26 [==============================] - 1s 54ms/step - loss: 0.0138 - mse: 0.0138 - mae: 0.0964
# Epoch 3/10
# 26/26 [==============================] - 2s 67ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0593
# Epoch 4/10
# 26/26 [==============================] - 2s 69ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0469
# Epoch 5/10
# 26/26 [==============================] - 1s 57ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0422
# Epoch 6/10
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0376
# Epoch 7/10
# 26/26 [==============================] - 1s 41ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0302
# Epoch 8/10
# 26/26 [==============================] - 1s 42ms/step - loss: 9.0699e-04 - mse: 9.0699e-04 - mae: 0.0238
# Epoch 9/10
# 26/26 [==============================] - 1s 43ms/step - loss: 6.1053e-04 - mse: 6.1053e-04 - mae: 0.0191
# Epoch 10/10
# 26/26 [==============================] - 1s 42ms/step - loss: 4.6467e-04 - mse: 4.6467e-04 - mae: 0.0166
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0312
#
# Test MSE: 0.0013716359389945865
# Test RMSE: 0.037035603667209024
# Test MAE: 0.03124573454260826

# %% [markdown]
# # N5M10

# %%
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_N5M10, test_size=0.2, random_state=42)

# %%
print("model1 of N5M10\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model1 of N5M10
#
# Epoch 1/10
# 26/26 [==============================] - 1s 10ms/step - loss: 0.0776 - mse: 0.0776 - mae: 0.2188
# Epoch 2/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0439 - mse: 0.0439 - mae: 0.1739
# Epoch 3/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0113 - mse: 0.0113 - mae: 0.0855
# Epoch 4/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0473
# Epoch 5/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0294
# Epoch 6/10
# 26/26 [==============================] - 0s 11ms/step - loss: 7.6413e-04 - mse: 7.6413e-04 - mae: 0.0204
# Epoch 7/10
# 26/26 [==============================] - 0s 10ms/step - loss: 5.7020e-04 - mse: 5.7020e-04 - mae: 0.0171
# Epoch 8/10
# 26/26 [==============================] - 0s 10ms/step - loss: 5.2050e-04 - mse: 5.2050e-04 - mae: 0.0166
# Epoch 9/10
# 26/26 [==============================] - 0s 10ms/step - loss: 4.7441e-04 - mse: 4.7441e-04 - mae: 0.0162
# Epoch 10/10
# 26/26 [==============================] - 0s 11ms/step - loss: 6.2052e-04 - mse: 6.2052e-04 - mae: 0.0181
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0523
#
# Test MSE: 0.0042813788168132305
# Test RMSE: 0.06543224600159489
# Test MAE: 0.05234655365347862

# %%
print("model2 of N5M10\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(3124,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model2 of N5M10
#
# Epoch 1/10
# 26/26 [==============================] - 2s 46ms/step - loss: 0.0659 - mse: 0.0659 - mae: 0.1790
# Epoch 2/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0184 - mse: 0.0184 - mae: 0.1133
# Epoch 3/10
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0660
# Epoch 4/10
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0492
# Epoch 5/10
# 26/26 [==============================] - 1s 56ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0320
# Epoch 6/10
# 26/26 [==============================] - 2s 66ms/step - loss: 9.9591e-04 - mse: 9.9591e-04 - mae: 0.0241
# Epoch 7/10
# 26/26 [==============================] - 1s 56ms/step - loss: 6.6202e-04 - mse: 6.6202e-04 - mae: 0.0199
# Epoch 8/10
# 26/26 [==============================] - 1s 43ms/step - loss: 4.7769e-04 - mse: 4.7769e-04 - mae: 0.0169
# Epoch 9/10
# 26/26 [==============================] - 2s 61ms/step - loss: 4.7930e-04 - mse: 4.7930e-04 - mae: 0.0166
# Epoch 10/10
# 26/26 [==============================] - 1s 43ms/step - loss: 4.2019e-04 - mse: 4.2019e-04 - mae: 0.0153
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0432
#
# Test MSE: 0.002480837982147932
# Test RMSE: 0.04980801122458045
# Test MAE: 0.04319719970226288

# %% [markdown]
# #N5M100

# %%
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_N5M100, test_size=0.2, random_state=42)

# %%
print("model1 of N5M100\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model1 of N5M100
#
# Epoch 1/10
# 26/26 [==============================] - 1s 10ms/step - loss: 0.1211 - mse: 0.1211 - mae: 0.2722
# Epoch 2/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0433 - mse: 0.0433 - mae: 0.1714
# Epoch 3/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0827
# Epoch 4/10
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0427
# Epoch 5/10
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0249
# Epoch 6/10
# 26/26 [==============================] - 0s 10ms/step - loss: 5.0944e-04 - mse: 5.0944e-04 - mae: 0.0174
# Epoch 7/10
# 26/26 [==============================] - 0s 10ms/step - loss: 2.7926e-04 - mse: 2.7926e-04 - mae: 0.0124
# Epoch 8/10
# 26/26 [==============================] - 0s 13ms/step - loss: 2.1401e-04 - mse: 2.1401e-04 - mae: 0.0104
# Epoch 9/10
# 26/26 [==============================] - 0s 12ms/step - loss: 1.8653e-04 - mse: 1.8653e-04 - mae: 0.0098
# Epoch 10/10
# 26/26 [==============================] - 1s 21ms/step - loss: 2.0039e-04 - mse: 2.0039e-04 - mae: 0.0096
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0645
#
# Test MSE: 0.0061326660215854645
# Test RMSE: 0.07831134031278908
# Test MAE: 0.06447983533143997

# %%
print("model2 of N5M100\n")

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_shape=(3124,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='linear')
])

# Compile
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mse', 'mae'])

# Train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate
loss, mse, mae = model.evaluate(X_test, y_test)
print('\nTest MSE:', mse)
print('Test RMSE:', np.sqrt(mse))
print('Test MAE:', mae)
# Out:
# model2 of N5M100
#
# Epoch 1/10
# 26/26 [==============================] - 2s 44ms/step - loss: 0.0683 - mse: 0.0683 - mae: 0.1773
# Epoch 2/10
# 26/26 [==============================] - 1s 44ms/step - loss: 0.0181 - mse: 0.0181 - mae: 0.1083
# Epoch 3/10
# 26/26 [==============================] - 1s 46ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0656
# Epoch 4/10
# 26/26 [==============================] - 1s 48ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0469
# Epoch 5/10
# 26/26 [==============================] - 1s 42ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0378
# Epoch 6/10
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0315
# Epoch 7/10
# 26/26 [==============================] - 1s 43ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0263
# Epoch 8/10
# 26/26 [==============================] - 2s 81ms/step - loss: 9.4461e-04 - mse: 9.4461e-04 - mae: 0.0239
# Epoch 9/10
# 26/26 [==============================] - 2s 66ms/step - loss: 7.3474e-04 - mse: 7.3474e-04 - mae: 0.0205
# Epoch 10/10
# 26/26 [==============================] - 2s 64ms/step - loss: 6.0946e-04 - mse: 6.0946e-04 - mae: 0.0186
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0509
#
# Test MSE: 0.003701569279655814
# Test RMSE: 0.06084052333482853
# Test MAE: 0.050853803753852844
